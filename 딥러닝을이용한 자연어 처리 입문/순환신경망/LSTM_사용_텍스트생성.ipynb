# %% [markdown]
# # LSTM 이용하여 텍스트 생성하기

# %% [markdown]
# #### 1) 데이터에 대한 이해와 전처리

# %%
import numpy as np
import pandas as pd
from string import punctuation

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical

# %%
df = pd.read_csv('ArticlesApril2018.csv')
df.head()
# Out:
#                   articleID  articleWordCount  \
# 0  5adf6684068401528a2aa69b               781
# 1  5adf653f068401528a2aa697               656
# 2  5adf4626068401528a2aa628              2427
# 3  5adf40d2068401528a2aa619               626
# 4  5adf3d64068401528a2aa60f               815
#
#                                       byline documentType  \
# 0                             By JOHN BRANCH      article
# 1                           By LISA FRIEDMAN      article
# 2                              By PETE WELLS      article
# 3  By JULIE HIRSCHFELD DAVIS and PETER BAKER      article
# 4             By IAN AUSTEN and DAN BILEFSKY      article
#
#                                             headline  \
# 0  Former N.F.L. Cheerleaders’ Settlement Offer: ...
# 1  E.P.A. to Unveil a New Rule. Its Effect: Less ...
# 2                            The New Noma, Explained
# 3                                            Unknown
# 4                                            Unknown
#
#                                             keywords  multimedia     newDesk  \
# 0  ['Workplace Hazards and Violations', 'Football...          68      Sports
# 1  ['Environmental Protection Agency', 'Pruitt, S...          68     Climate
# 2  ['Restaurants', 'Noma (Copenhagen, Restaurant)...          66      Dining
# 3  ['Macron, Emmanuel (1977- )', 'Trump, Donald J...          68  Washington
# 4  ['Toronto, Ontario, Attack (April, 2018)', 'Mu...          68     Foreign
#
#    printPage              pubDate   sectionName  \
# 0          0  2018-04-24 17:16:49  Pro Football
# 1          0  2018-04-24 17:11:21       Unknown
# 2          0  2018-04-24 14:58:44       Unknown
# 3          0  2018-04-24 14:35:57        Europe
# 4          0  2018-04-24 14:21:21        Canada
#
#                                              snippet              source  \
# 0  “I understand that they could meet with us, pa...  The New York Times
# 1  The agency plans to publish a new regulation T...  The New York Times
# 2  What’s it like to eat at the second incarnatio...  The New York Times
# 3  President Trump welcomed President Emmanuel Ma...  The New York Times
# 4  Alek Minassian, 25, a resident of Toronto’s Ri...  The New York Times
#
#   typeOfMaterial                                             webURL
# 0           News  https://www.nytimes.com/2018/04/24/sports/foot...
# 1           News  https://www.nytimes.com/2018/04/24/climate/epa...
# 2           News  https://www.nytimes.com/2018/04/24/dining/noma...
# 3           News  https://www.nytimes.com/2018/04/24/world/europ...
# 4           News  https://www.nytimes.com/2018/04/24/world/canad...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1324 entries, 0 to 1323
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   articleID         1324 non-null   object
#  1   articleWordCount  1324 non-null   int64
#  2   byline            1324 non-null   object
#  3   documentType      1324 non-null   object
#  4   headline          1324 non-null   object
#  5   keywords          1324 non-null   object
#  6   multimedia        1324 non-null   int64
#  7   newDesk           1324 non-null   object
#  8   printPage         1324 non-null   int64
#  9   pubDate           1324 non-null   object
#  10  sectionName       1324 non-null   object
#  11  snippet           1324 non-null   object
#  12  source            1324 non-null   object
#  13  typeOfMaterial    1324 non-null   object
#  14  webURL            1324 non-null   object
# dtypes: int64(3), object(12)
# memory usage: 155.3+ KB

# %%
headline= []
headline.extend(list(df['headline'].values))
headline[:5]
# Out:
# ['Former N.F.L. Cheerleaders’ Settlement Offer: $1 and a Meeting With Goodell',
#  'E.P.A. to Unveil a New Rule. Its Effect: Less Science in Policymaking.',
#  'The New Noma, Explained',
#  'Unknown',
#  'Unknown']

# %%
headline = [word for word in headline if word!='Unknown']
print('노이즈 제거 후 개수 :',len(headline))
# Out:
# 노이즈 제거 후 개수 : 1214

# %%
# 구두점 제거 및 소문자화
def repreprocessing(sentence):
    preprocessed_sentence = sentence.encode('utf8').decode('ascii', 'ignore')
    return ''.join(word for word in preprocessed_sentence if word not in punctuation).lower()

# %%
preprocessed_headline = [repreprocessing(x) for x in headline]
preprocessed_headline[:5]
# Out:
# ['former nfl cheerleaders settlement offer 1 and a meeting with goodell',
#  'epa to unveil a new rule its effect less science in policymaking',
#  'the new noma explained',
#  'how a bag of texas dirt  became a times tradition',
#  'is school a place for selfexpression']

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(preprocessed_headline)
vocab_size = len(tokenizer.word_index)+1
print("단어 집합 크기 : ", vocab_size)
# Out:
# 단어 집합 크기 :  3494

# %%
sequences = list()

for sentence in preprocessed_headline:
    # 각 샘플에 대해 정수 인코딩
    encoded = tokenizer.texts_to_sequences([sentence])[0]
    for i in range(1, len(encoded)):
        sequence = encoded[:i+1]
        sequences.append(sequence)

# %%
sequences[:11]
# Out:
# [[99, 269],
#  [99, 269, 371],
#  [99, 269, 371, 1115],
#  [99, 269, 371, 1115, 582],
#  [99, 269, 371, 1115, 582, 52],
#  [99, 269, 371, 1115, 582, 52, 7],
#  [99, 269, 371, 1115, 582, 52, 7, 2],
#  [99, 269, 371, 1115, 582, 52, 7, 2, 372],
#  [99, 269, 371, 1115, 582, 52, 7, 2, 372, 10],
#  [99, 269, 371, 1115, 582, 52, 7, 2, 372, 10, 1116],
#  [100, 3]]

# %% [markdown]
# 하나의 문장을 단어 하나씩 추가하는 이유
# - 하나의 단어를 예측하기 위해 이전에 등장한 단어들을 모두 참고하는 것
# - 즉 각 시점(time step)마다 하나씩 추가적으로 등장하는 형태
# - 마지막에 예측할 단어에 해당되는 레이블을 분리하는 작업을 수행
#     - index_to_word 활용

# %%
index_to_word = {}
for key, value in tokenizer.word_index.items():
    index_to_word[value]=key

# %%
print("빈도수 상위 582번 단어 : {}".format(index_to_word[582]))
# Out:
# 빈도수 상위 582번 단어 : offer

# %%
max_len = max(len(l) for l in sequences)
print("샘플 최대 길이 :",max_len)
# Out:
# 샘플 최대 길이 : 24

# %%
sequences = pad_sequences(sequences, maxlen=max_len, padding='pre')

# %%
sequences = np.array(sequences)
X = sequences[:,:-1]
y = sequences[:, -1]

# %%
y = to_categorical(y, num_classes=vocab_size)

# %% [markdown]
# #### 2.) 모델 설계하기

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Dense, LSTM

# import tensorflow as tf
# config = tf.compat.v1.ConfigProto() 
# config.gpu_options.allow_growth = True


model = Sequential()
model.add(Embedding(vocab_size, 10))
model.add(LSTM(128))
model.add(Dense(vocab_size, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X, y , epochs=200, verbose=2)
# Out:
# Epoch 1/200
# 244/244 - 4s - loss: 7.6440 - accuracy: 0.0247 - 4s/epoch - 17ms/step
# Epoch 2/200
# 244/244 - 2s - loss: 7.1193 - accuracy: 0.0286 - 2s/epoch - 6ms/step
# Epoch 3/200
# 244/244 - 2s - loss: 6.9830 - accuracy: 0.0350 - 2s/epoch - 6ms/step
# Epoch 4/200
# 244/244 - 2s - loss: 6.8540 - accuracy: 0.0408 - 2s/epoch - 7ms/step
# Epoch 5/200
# 244/244 - 2s - loss: 6.6995 - accuracy: 0.0469 - 2s/epoch - 7ms/step
# Epoch 6/200
# 244/244 - 2s - loss: 6.5329 - accuracy: 0.0502 - 2s/epoch - 6ms/step
# Epoch 7/200
# 244/244 - 2s - loss: 6.3542 - accuracy: 0.0500 - 2s/epoch - 7ms/step
# Epoch 8/200
# 244/244 - 2s - loss: 6.1628 - accuracy: 0.0566 - 2s/epoch - 6ms/step
# Epoch 9/200
# 244/244 - 2s - loss: 5.9640 - accuracy: 0.0627 - 2s/epoch - 6ms/step
# Epoch 10/200
# 244/244 - 2s - loss: 5.7752 - accuracy: 0.0689 - 2s/epoch - 7ms/step
# Epoch 11/200
# 244/244 - 2s - loss: 5.5961 - accuracy: 0.0729 - 2s/epoch - 6ms/step
# Epoch 12/200
# 244/244 - 2s - loss: 5.4264 - accuracy: 0.0755 - 2s/epoch - 6ms/step
# Epoch 13/200
# 244/244 - 1s - loss: 5.2631 - accuracy: 0.0821 - 1s/epoch - 6ms/step
# Epoch 14/200
# 244/244 - 1s - loss: 5.1072 - accuracy: 0.0869 - 1s/epoch - 6ms/step
# Epoch 15/200
# 244/244 - 1s - loss: 4.9604 - accuracy: 0.0970 - 1s/epoch - 6ms/step
# Epoch 16/200
# 244/244 - 2s - loss: 4.8134 - accuracy: 0.1033 - 2s/epoch - 6ms/step
# Epoch 17/200
# 244/244 - 1s - loss: 4.6775 - accuracy: 0.1194 - 1s/epoch - 6ms/step
# Epoch 18/200
# 244/244 - 2s - loss: 4.5432 - accuracy: 0.1365 - 2s/epoch - 6ms/step
# Epoch 19/200
# 244/244 - 2s - loss: 4.4159 - accuracy: 0.1496 - 2s/epoch - 7ms/step
# Epoch 20/200
# 244/244 - 2s - loss: 4.2903 - accuracy: 0.1675 - 2s/epoch - 7ms/step
# Epoch 21/200
# 244/244 - 2s - loss: 4.1712 - accuracy: 0.1863 - 2s/epoch - 7ms/step
# Epoch 22/200
# 244/244 - 2s - loss: 4.0555 - accuracy: 0.2050 - 2s/epoch - 6ms/step
# Epoch 23/200
# 244/244 - 2s - loss: 3.9431 - accuracy: 0.2261 - 2s/epoch - 6ms/step
# Epoch 24/200
# 244/244 - 2s - loss: 3.8332 - accuracy: 0.2371 - 2s/epoch - 6ms/step
# Epoch 25/200
# 244/244 - 2s - loss: 3.7293 - accuracy: 0.2582 - 2s/epoch - 6ms/step
# Epoch 26/200
# 244/244 - 2s - loss: 3.6285 - accuracy: 0.2731 - 2s/epoch - 6ms/step
# Epoch 27/200
# 244/244 - 2s - loss: 3.5291 - accuracy: 0.2900 - 2s/epoch - 6ms/step
# Epoch 28/200
# 244/244 - 2s - loss: 3.4346 - accuracy: 0.3094 - 2s/epoch - 6ms/step
# Epoch 29/200
# 244/244 - 2s - loss: 3.3447 - accuracy: 0.3249 - 2s/epoch - 6ms/step
# Epoch 30/200
# 244/244 - 1s - loss: 3.2565 - accuracy: 0.3453 - 1s/epoch - 6ms/step
# Epoch 31/200
# 244/244 - 1s - loss: 3.1713 - accuracy: 0.3574 - 1s/epoch - 6ms/step
# Epoch 32/200
# 244/244 - 1s - loss: 3.0904 - accuracy: 0.3704 - 1s/epoch - 6ms/step
# Epoch 33/200
# 244/244 - 1s - loss: 3.0128 - accuracy: 0.3923 - 1s/epoch - 6ms/step
# Epoch 34/200
# 244/244 - 1s - loss: 2.9375 - accuracy: 0.4029 - 1s/epoch - 6ms/step
# Epoch 35/200
# 244/244 - 1s - loss: 2.8657 - accuracy: 0.4171 - 1s/epoch - 6ms/step
# Epoch 36/200
# 244/244 - 1s - loss: 2.7954 - accuracy: 0.4256 - 1s/epoch - 6ms/step
# Epoch 37/200
# 244/244 - 1s - loss: 2.7277 - accuracy: 0.4391 - 1s/epoch - 6ms/step
# Epoch 38/200
# 244/244 - 1s - loss: 2.6612 - accuracy: 0.4579 - 1s/epoch - 6ms/step
# Epoch 39/200
# 244/244 - 1s - loss: 2.5995 - accuracy: 0.4639 - 1s/epoch - 6ms/step
# Epoch 40/200
# 244/244 - 1s - loss: 2.5395 - accuracy: 0.4774 - 1s/epoch - 6ms/step
# Epoch 41/200
# 244/244 - 2s - loss: 2.4791 - accuracy: 0.4897 - 2s/epoch - 6ms/step
# Epoch 42/200
# 244/244 - 1s - loss: 2.4274 - accuracy: 0.4993 - 1s/epoch - 6ms/step
# Epoch 43/200
# 244/244 - 1s - loss: 2.3686 - accuracy: 0.5101 - 1s/epoch - 6ms/step
# Epoch 44/200
# 244/244 - 1s - loss: 2.3120 - accuracy: 0.5256 - 1s/epoch - 6ms/step
# Epoch 45/200
# 244/244 - 1s - loss: 2.2604 - accuracy: 0.5325 - 1s/epoch - 6ms/step
# Epoch 46/200
# 244/244 - 1s - loss: 2.2101 - accuracy: 0.5470 - 1s/epoch - 6ms/step
# Epoch 47/200
# 244/244 - 1s - loss: 2.1578 - accuracy: 0.5552 - 1s/epoch - 6ms/step
# Epoch 48/200
# 244/244 - 1s - loss: 2.1103 - accuracy: 0.5667 - 1s/epoch - 6ms/step
# Epoch 49/200
# 244/244 - 1s - loss: 2.0603 - accuracy: 0.5799 - 1s/epoch - 6ms/step
# Epoch 50/200
# 244/244 - 1s - loss: 2.0142 - accuracy: 0.5855 - 1s/epoch - 6ms/step
# Epoch 51/200
# 244/244 - 1s - loss: 1.9695 - accuracy: 0.6000 - 1s/epoch - 6ms/step
# Epoch 52/200
# 244/244 - 1s - loss: 1.9233 - accuracy: 0.6096 - 1s/epoch - 6ms/step
# Epoch 53/200
# 244/244 - 1s - loss: 1.8800 - accuracy: 0.6207 - 1s/epoch - 6ms/step
# Epoch 54/200
# 244/244 - 1s - loss: 1.8370 - accuracy: 0.6312 - 1s/epoch - 6ms/step
# Epoch 55/200
# 244/244 - 1s - loss: 1.7938 - accuracy: 0.6412 - 1s/epoch - 6ms/step
# Epoch 56/200
# 244/244 - 1s - loss: 1.7548 - accuracy: 0.6454 - 1s/epoch - 6ms/step
# Epoch 57/200
# 244/244 - 1s - loss: 1.7140 - accuracy: 0.6535 - 1s/epoch - 6ms/step
# Epoch 58/200
# 244/244 - 2s - loss: 1.6731 - accuracy: 0.6676 - 2s/epoch - 6ms/step
# Epoch 59/200
# 244/244 - 2s - loss: 1.6366 - accuracy: 0.6712 - 2s/epoch - 7ms/step
# Epoch 60/200
# 244/244 - 2s - loss: 1.5981 - accuracy: 0.6800 - 2s/epoch - 7ms/step
# Epoch 61/200
# 244/244 - 2s - loss: 1.5605 - accuracy: 0.6896 - 2s/epoch - 7ms/step
# Epoch 62/200
# 244/244 - 2s - loss: 1.5240 - accuracy: 0.6990 - 2s/epoch - 7ms/step
# Epoch 63/200
# 244/244 - 2s - loss: 1.4882 - accuracy: 0.7006 - 2s/epoch - 6ms/step
# Epoch 64/200
# 244/244 - 2s - loss: 1.4593 - accuracy: 0.7127 - 2s/epoch - 8ms/step
# Epoch 65/200
# 244/244 - 3s - loss: 1.4197 - accuracy: 0.7173 - 3s/epoch - 10ms/step
# Epoch 66/200
# 244/244 - 2s - loss: 1.3898 - accuracy: 0.7240 - 2s/epoch - 9ms/step
# Epoch 67/200
# 244/244 - 2s - loss: 1.3575 - accuracy: 0.7286 - 2s/epoch - 10ms/step
# Epoch 68/200
# 244/244 - 2s - loss: 1.3244 - accuracy: 0.7395 - 2s/epoch - 10ms/step
# Epoch 69/200
# 244/244 - 3s - loss: 1.2936 - accuracy: 0.7439 - 3s/epoch - 11ms/step
# Epoch 70/200
# 244/244 - 3s - loss: 1.2652 - accuracy: 0.7437 - 3s/epoch - 11ms/step
# Epoch 71/200
# 244/244 - 3s - loss: 1.2360 - accuracy: 0.7545 - 3s/epoch - 11ms/step
# Epoch 72/200
# 244/244 - 2s - loss: 1.2058 - accuracy: 0.7598 - 2s/epoch - 8ms/step
# Epoch 73/200
# 244/244 - 3s - loss: 1.1796 - accuracy: 0.7684 - 3s/epoch - 11ms/step
# Epoch 74/200
# 244/244 - 2s - loss: 1.1495 - accuracy: 0.7750 - 2s/epoch - 10ms/step
# Epoch 75/200
# 244/244 - 3s - loss: 1.1234 - accuracy: 0.7805 - 3s/epoch - 11ms/step
# Epoch 76/200
# 244/244 - 3s - loss: 1.0977 - accuracy: 0.7829 - 3s/epoch - 11ms/step
# Epoch 77/200
# 244/244 - 2s - loss: 1.0751 - accuracy: 0.7873 - 2s/epoch - 10ms/step
# Epoch 78/200
# 244/244 - 2s - loss: 1.0468 - accuracy: 0.7946 - 2s/epoch - 10ms/step
# Epoch 79/200
# 244/244 - 2s - loss: 1.0226 - accuracy: 0.8014 - 2s/epoch - 10ms/step
# Epoch 80/200
# 244/244 - 2s - loss: 1.0000 - accuracy: 0.8047 - 2s/epoch - 10ms/step
# Epoch 81/200
# 244/244 - 2s - loss: 0.9817 - accuracy: 0.8064 - 2s/epoch - 9ms/step
# Epoch 82/200
# 244/244 - 2s - loss: 0.9569 - accuracy: 0.8131 - 2s/epoch - 10ms/step
# Epoch 83/200
# 244/244 - 2s - loss: 0.9326 - accuracy: 0.8156 - 2s/epoch - 10ms/step
# Epoch 84/200
# 244/244 - 2s - loss: 0.9100 - accuracy: 0.8203 - 2s/epoch - 9ms/step
# Epoch 85/200
# 244/244 - 2s - loss: 0.8913 - accuracy: 0.8242 - 2s/epoch - 7ms/step
# Epoch 86/200
# 244/244 - 2s - loss: 0.8704 - accuracy: 0.8271 - 2s/epoch - 7ms/step
# Epoch 87/200
# 244/244 - 2s - loss: 0.8483 - accuracy: 0.8348 - 2s/epoch - 9ms/step
# Epoch 88/200
# 244/244 - 2s - loss: 0.8305 - accuracy: 0.8339 - 2s/epoch - 9ms/step
# Epoch 89/200
# 244/244 - 3s - loss: 0.8102 - accuracy: 0.8392 - 3s/epoch - 11ms/step
# Epoch 90/200
# 244/244 - 2s - loss: 0.7920 - accuracy: 0.8439 - 2s/epoch - 10ms/step
# Epoch 91/200
# 244/244 - 2s - loss: 0.7756 - accuracy: 0.8463 - 2s/epoch - 8ms/step
# Epoch 92/200
# 244/244 - 2s - loss: 0.7582 - accuracy: 0.8501 - 2s/epoch - 9ms/step
# Epoch 93/200
# 244/244 - 2s - loss: 0.7421 - accuracy: 0.8525 - 2s/epoch - 9ms/step
# Epoch 94/200
# 244/244 - 2s - loss: 0.7259 - accuracy: 0.8543 - 2s/epoch - 10ms/step
# Epoch 95/200
# 244/244 - 2s - loss: 0.7091 - accuracy: 0.8597 - 2s/epoch - 10ms/step
# Epoch 96/200
# 244/244 - 3s - loss: 0.6926 - accuracy: 0.8652 - 3s/epoch - 11ms/step
# Epoch 97/200
# 244/244 - 2s - loss: 0.6785 - accuracy: 0.8629 - 2s/epoch - 10ms/step
# Epoch 98/200
# 244/244 - 3s - loss: 0.6635 - accuracy: 0.8683 - 3s/epoch - 10ms/step
# Epoch 99/200
# 244/244 - 3s - loss: 0.6496 - accuracy: 0.8709 - 3s/epoch - 11ms/step
# Epoch 100/200
# 244/244 - 3s - loss: 0.6355 - accuracy: 0.8712 - 3s/epoch - 11ms/step
# Epoch 101/200
# 244/244 - 2s - loss: 0.6219 - accuracy: 0.8775 - 2s/epoch - 8ms/step
# Epoch 102/200
# 244/244 - 2s - loss: 0.6100 - accuracy: 0.8790 - 2s/epoch - 7ms/step
# Epoch 103/200
# 244/244 - 3s - loss: 0.5983 - accuracy: 0.8795 - 3s/epoch - 11ms/step
# Epoch 104/200
# 244/244 - 3s - loss: 0.5854 - accuracy: 0.8840 - 3s/epoch - 12ms/step
# Epoch 105/200
# 244/244 - 3s - loss: 0.5722 - accuracy: 0.8859 - 3s/epoch - 10ms/step
# Epoch 106/200
# 244/244 - 2s - loss: 0.5616 - accuracy: 0.8874 - 2s/epoch - 6ms/step
# Epoch 107/200
# 244/244 - 2s - loss: 0.5497 - accuracy: 0.8906 - 2s/epoch - 7ms/step
# Epoch 108/200
# 244/244 - 2s - loss: 0.5397 - accuracy: 0.8918 - 2s/epoch - 9ms/step
# Epoch 109/200
# 244/244 - 2s - loss: 0.5382 - accuracy: 0.8922 - 2s/epoch - 8ms/step
# Epoch 110/200
# 244/244 - 2s - loss: 0.5190 - accuracy: 0.8953 - 2s/epoch - 10ms/step
# Epoch 111/200
# 244/244 - 2s - loss: 0.5073 - accuracy: 0.8999 - 2s/epoch - 10ms/step
# Epoch 112/200
# 244/244 - 2s - loss: 0.4973 - accuracy: 0.8979 - 2s/epoch - 8ms/step
# Epoch 113/200
# 244/244 - 2s - loss: 0.4883 - accuracy: 0.9011 - 2s/epoch - 7ms/step
# Epoch 114/200
# 244/244 - 2s - loss: 0.4799 - accuracy: 0.9023 - 2s/epoch - 9ms/step
# Epoch 115/200
# 244/244 - 2s - loss: 0.4705 - accuracy: 0.9032 - 2s/epoch - 9ms/step
# Epoch 116/200
# 244/244 - 2s - loss: 0.4630 - accuracy: 0.9035 - 2s/epoch - 8ms/step
# Epoch 117/200
# 244/244 - 2s - loss: 0.4553 - accuracy: 0.9044 - 2s/epoch - 9ms/step
# Epoch 118/200
# 244/244 - 2s - loss: 0.4466 - accuracy: 0.9055 - 2s/epoch - 10ms/step
# Epoch 119/200
# 244/244 - 3s - loss: 0.4391 - accuracy: 0.9061 - 3s/epoch - 10ms/step
# Epoch 120/200
# 244/244 - 2s - loss: 0.4345 - accuracy: 0.9063 - 2s/epoch - 10ms/step
# Epoch 121/200
# 244/244 - 2s - loss: 0.4270 - accuracy: 0.9091 - 2s/epoch - 10ms/step
# Epoch 122/200
# 244/244 - 2s - loss: 0.4179 - accuracy: 0.9091 - 2s/epoch - 9ms/step
# Epoch 123/200
# 244/244 - 2s - loss: 0.4111 - accuracy: 0.9091 - 2s/epoch - 10ms/step
# Epoch 124/200
# 244/244 - 2s - loss: 0.4038 - accuracy: 0.9126 - 2s/epoch - 9ms/step
# Epoch 125/200
# 244/244 - 2s - loss: 0.3981 - accuracy: 0.9121 - 2s/epoch - 9ms/step
# Epoch 126/200
# 244/244 - 2s - loss: 0.3919 - accuracy: 0.9114 - 2s/epoch - 10ms/step
# Epoch 127/200
# 244/244 - 2s - loss: 0.3906 - accuracy: 0.9122 - 2s/epoch - 9ms/step
# Epoch 128/200
# 244/244 - 2s - loss: 0.3815 - accuracy: 0.9126 - 2s/epoch - 9ms/step
# Epoch 129/200
# 244/244 - 2s - loss: 0.3754 - accuracy: 0.9117 - 2s/epoch - 9ms/step
# Epoch 130/200
# 244/244 - 2s - loss: 0.3720 - accuracy: 0.9129 - 2s/epoch - 10ms/step
# Epoch 131/200
# 244/244 - 2s - loss: 0.3656 - accuracy: 0.9150 - 2s/epoch - 9ms/step
# Epoch 132/200
# 244/244 - 3s - loss: 0.3620 - accuracy: 0.9136 - 3s/epoch - 11ms/step
# Epoch 133/200
# 244/244 - 3s - loss: 0.3593 - accuracy: 0.9148 - 3s/epoch - 10ms/step
# Epoch 134/200
# 244/244 - 3s - loss: 0.3541 - accuracy: 0.9139 - 3s/epoch - 11ms/step
# Epoch 135/200
# 244/244 - 3s - loss: 0.3511 - accuracy: 0.9154 - 3s/epoch - 10ms/step
# Epoch 136/200
# 244/244 - 3s - loss: 0.3526 - accuracy: 0.9150 - 3s/epoch - 10ms/step
# Epoch 137/200
# 244/244 - 3s - loss: 0.3453 - accuracy: 0.9155 - 3s/epoch - 11ms/step
# Epoch 138/200
# 244/244 - 2s - loss: 0.3373 - accuracy: 0.9136 - 2s/epoch - 9ms/step
# Epoch 139/200
# 244/244 - 2s - loss: 0.3343 - accuracy: 0.9152 - 2s/epoch - 9ms/step
# Epoch 140/200
# 244/244 - 3s - loss: 0.3317 - accuracy: 0.9159 - 3s/epoch - 11ms/step
# Epoch 141/200
# 244/244 - 3s - loss: 0.3276 - accuracy: 0.9162 - 3s/epoch - 11ms/step
# Epoch 142/200
# 244/244 - 2s - loss: 0.3242 - accuracy: 0.9144 - 2s/epoch - 9ms/step
# Epoch 143/200
# 244/244 - 2s - loss: 0.3218 - accuracy: 0.9150 - 2s/epoch - 10ms/step
# Epoch 144/200
# 244/244 - 2s - loss: 0.3196 - accuracy: 0.9161 - 2s/epoch - 9ms/step
# Epoch 145/200
# 244/244 - 2s - loss: 0.3168 - accuracy: 0.9162 - 2s/epoch - 8ms/step
# Epoch 146/200
# 244/244 - 2s - loss: 0.3145 - accuracy: 0.9154 - 2s/epoch - 9ms/step
# Epoch 147/200
# 244/244 - 2s - loss: 0.3116 - accuracy: 0.9150 - 2s/epoch - 8ms/step
# Epoch 148/200
# 244/244 - 2s - loss: 0.3126 - accuracy: 0.9163 - 2s/epoch - 10ms/step
# Epoch 149/200
# 244/244 - 2s - loss: 0.3143 - accuracy: 0.9144 - 2s/epoch - 9ms/step
# Epoch 150/200
# 244/244 - 3s - loss: 0.3158 - accuracy: 0.9146 - 3s/epoch - 11ms/step
# Epoch 151/200
# 244/244 - 2s - loss: 0.3081 - accuracy: 0.9163 - 2s/epoch - 10ms/step
# Epoch 152/200
# 244/244 - 2s - loss: 0.3072 - accuracy: 0.9162 - 2s/epoch - 9ms/step
# Epoch 153/200
# 244/244 - 2s - loss: 0.3124 - accuracy: 0.9150 - 2s/epoch - 9ms/step
# Epoch 154/200
# 244/244 - 3s - loss: 0.3023 - accuracy: 0.9164 - 3s/epoch - 11ms/step
# Epoch 155/200
# 244/244 - 2s - loss: 0.2974 - accuracy: 0.9175 - 2s/epoch - 10ms/step
# Epoch 156/200
# 244/244 - 3s - loss: 0.2958 - accuracy: 0.9173 - 3s/epoch - 10ms/step
# Epoch 157/200
# 244/244 - 3s - loss: 0.2946 - accuracy: 0.9155 - 3s/epoch - 10ms/step
# Epoch 158/200
# 244/244 - 2s - loss: 0.2937 - accuracy: 0.9166 - 2s/epoch - 10ms/step
# Epoch 159/200
# 244/244 - 3s - loss: 0.2923 - accuracy: 0.9143 - 3s/epoch - 10ms/step
# Epoch 160/200
# 244/244 - 2s - loss: 0.2901 - accuracy: 0.9168 - 2s/epoch - 10ms/step
# Epoch 161/200
# 244/244 - 2s - loss: 0.2886 - accuracy: 0.9172 - 2s/epoch - 10ms/step
# Epoch 162/200
# 244/244 - 2s - loss: 0.2878 - accuracy: 0.9152 - 2s/epoch - 10ms/step
# Epoch 163/200
# 244/244 - 2s - loss: 0.2877 - accuracy: 0.9162 - 2s/epoch - 9ms/step
# Epoch 164/200
# 244/244 - 2s - loss: 0.2854 - accuracy: 0.9172 - 2s/epoch - 9ms/step
# Epoch 165/200
# 244/244 - 2s - loss: 0.2833 - accuracy: 0.9164 - 2s/epoch - 10ms/step
# Epoch 166/200
# 244/244 - 2s - loss: 0.2837 - accuracy: 0.9148 - 2s/epoch - 10ms/step
# Epoch 167/200
# 244/244 - 3s - loss: 0.2818 - accuracy: 0.9175 - 3s/epoch - 11ms/step
# Epoch 168/200
# 244/244 - 2s - loss: 0.2912 - accuracy: 0.9145 - 2s/epoch - 10ms/step
# Epoch 169/200
# 244/244 - 3s - loss: 0.3363 - accuracy: 0.9085 - 3s/epoch - 10ms/step
# Epoch 170/200
# 244/244 - 2s - loss: 0.3042 - accuracy: 0.9116 - 2s/epoch - 10ms/step
# Epoch 171/200
# 244/244 - 3s - loss: 0.2812 - accuracy: 0.9159 - 3s/epoch - 10ms/step
# Epoch 172/200
# 244/244 - 2s - loss: 0.2770 - accuracy: 0.9164 - 2s/epoch - 10ms/step
# Epoch 173/200
# 244/244 - 3s - loss: 0.2748 - accuracy: 0.9164 - 3s/epoch - 10ms/step
# Epoch 174/200
# 244/244 - 2s - loss: 0.2729 - accuracy: 0.9175 - 2s/epoch - 10ms/step
# Epoch 175/200
# 244/244 - 3s - loss: 0.2741 - accuracy: 0.9167 - 3s/epoch - 11ms/step
# Epoch 176/200
# 244/244 - 3s - loss: 0.2733 - accuracy: 0.9158 - 3s/epoch - 11ms/step
# Epoch 177/200
# 244/244 - 3s - loss: 0.2733 - accuracy: 0.9170 - 3s/epoch - 12ms/step
# Epoch 178/200
# 244/244 - 3s - loss: 0.2721 - accuracy: 0.9166 - 3s/epoch - 11ms/step
# Epoch 179/200
# 244/244 - 3s - loss: 0.2726 - accuracy: 0.9164 - 3s/epoch - 11ms/step
# Epoch 180/200
# 244/244 - 3s - loss: 0.2717 - accuracy: 0.9176 - 3s/epoch - 11ms/step
# Epoch 181/200
# 244/244 - 2s - loss: 0.2705 - accuracy: 0.9164 - 2s/epoch - 10ms/step
# Epoch 182/200
# 244/244 - 2s - loss: 0.2705 - accuracy: 0.9168 - 2s/epoch - 10ms/step
# Epoch 183/200
# 244/244 - 3s - loss: 0.2706 - accuracy: 0.9163 - 3s/epoch - 11ms/step
# Epoch 184/200
# 244/244 - 3s - loss: 0.2703 - accuracy: 0.9162 - 3s/epoch - 11ms/step
# Epoch 185/200
# 244/244 - 2s - loss: 0.2706 - accuracy: 0.9150 - 2s/epoch - 10ms/step
# Epoch 186/200
# 244/244 - 2s - loss: 0.2696 - accuracy: 0.9152 - 2s/epoch - 10ms/step
# Epoch 187/200
# 244/244 - 2s - loss: 0.2683 - accuracy: 0.9164 - 2s/epoch - 10ms/step
# Epoch 188/200
# 244/244 - 2s - loss: 0.2684 - accuracy: 0.9162 - 2s/epoch - 10ms/step
# Epoch 189/200
# 244/244 - 3s - loss: 0.2684 - accuracy: 0.9171 - 3s/epoch - 10ms/step
# Epoch 190/200
# 244/244 - 2s - loss: 0.2704 - accuracy: 0.9166 - 2s/epoch - 10ms/step
# Epoch 191/200
# 244/244 - 2s - loss: 0.2934 - accuracy: 0.9112 - 2s/epoch - 9ms/step
# Epoch 192/200
# 244/244 - 2s - loss: 0.2854 - accuracy: 0.9139 - 2s/epoch - 8ms/step
# Epoch 193/200
# 244/244 - 2s - loss: 0.2701 - accuracy: 0.9158 - 2s/epoch - 9ms/step
# Epoch 194/200
# 244/244 - 3s - loss: 0.2651 - accuracy: 0.9168 - 3s/epoch - 11ms/step
# Epoch 195/200
# 244/244 - 3s - loss: 0.2637 - accuracy: 0.9164 - 3s/epoch - 12ms/step
# Epoch 196/200
# 244/244 - 3s - loss: 0.2635 - accuracy: 0.9157 - 3s/epoch - 10ms/step
# Epoch 197/200
# 244/244 - 2s - loss: 0.2636 - accuracy: 0.9177 - 2s/epoch - 10ms/step
# Epoch 198/200
# 244/244 - 3s - loss: 0.2628 - accuracy: 0.9179 - 3s/epoch - 12ms/step
# Epoch 199/200
# 244/244 - 3s - loss: 0.2630 - accuracy: 0.9153 - 3s/epoch - 12ms/step
# Epoch 200/200
# 244/244 - 3s - loss: 0.2634 - accuracy: 0.9168 - 3s/epoch - 11ms/step

# %%
def sentence_generation(model, tokenizer, current_word, n):
    init_word = current_word
    sentence = ''
    
    for _ in range(n):
        encoded = tokenizer.texts_to_sequences([current_word])[0]
        encoded = pad_sequences([encoded], maxlen=max_len-1, padding='pre')
        
        result = model.predict(encoded, verbose=0)
        result = np.argmax(result, axis=1)
        
        for word, index in tokenizer.word_index.items():
            if index==result:
                break
        
        current_word = current_word+' '+word
        
        sentence = sentence + ' ' +word
    sentence = init_word + sentence
    return sentence

# %%
print(sentence_generation(model, tokenizer, 'i', 10))
# Out:
# i disapprove of school vouchers can i still apply for them

# %%
print(sentence_generation(model, tokenizer, 'Game', 10))
# Out:
# Game your baby is your roommate workers the political firm nightmare

# %%
print(sentence_generation(model, tokenizer, 'how', 50))
# Out:
# how to make facebook more accountable rules the wrestling mommy and and more abuse party girls was it whats girls of was was admissions reimaginedjurassic classics reimaginedjurassic classics reimaginedjurassic classics reimaginedjurassic reimaginedjurassic fight reimaginedjurassic classics reimaginedjurassic reimaginedjurassic reimaginedjurassic given my do the absurdist office fire for a cathedral todo list todo
