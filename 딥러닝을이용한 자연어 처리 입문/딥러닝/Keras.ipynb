# %% [markdown]
# ## 1. 전처리(Preprocessing)
# - Tokenizer()
#     - 토큰화와 정수 인코딩에 사용
#     - 훈련 데이터로부터 단어 집합을 생성, 해당 단어 집합으로부터 임의의 문장을 정수 인코딩 해줌

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer()
train_text = 'The earth is an awesome place to live'

# 단어 집합 생성
tokenizer.fit_on_texts([train_text])     

# 정수 인코딩
sub_text = "The earth is an great place to live"
# 2차원이 결과로 나오기 때문에 [0] 추가해주기

sequences = tokenizer.texts_to_sequences([sub_text])[0]

print("정수 인코딩 : ", sequences)
# great 는 단어 집합(vocab)에 없기 때문에 출력되지 않는ㄷ.ㅏ
print("단어 집합 : ", tokenizer.word_index)
# Out:
# 정수 인코딩 :  [1, 2, 3, 4, 6, 7, 8]
# 단어 집합 :  {'the': 1, 'earth': 2, 'is': 3, 'an': 4, 'awesome': 5, 'place': 6, 'to': 7, 'live': 8}

# %% [markdown]
# - pad_sequence()
#     - 전체 훈련 데이터에서 각 샘플의 길이는 서로 다를 수 있다. 따라서 각 데이터의 길이를 맞추어야 하는데 이를 패딩이라고 한다.
#     - 보통 숫자 0을 넣어서 다른 샘플의 길이를 맞추어준다.
#     - pre 는 앞부터, Post는 뒤부터 0을 채워준다

# %%
pad_sequences([[1,2,3], [3,4,5,6], [7,8]], maxlen=3, padding='pre')
# Out:
# array([[1, 2, 3],
#        [4, 5, 6],
#        [0, 7, 8]], dtype=int32)

# %% [markdown]
# ## 2. Word Embedding
# - 텍스트 내의 단어들을 밀집 벡터(dense vector)로 만드는 것
#     - 원-핫 벡터에 비해 상대적으로 저차원을 가지며, 모든 원소의 값이 실수이다.
#     - Ex) [0.1 -1.2 0.8 0.2 1.8] # 상대적으로 저차원이며 실수값을 가짐
#
# - 임베딩 벡터는 초기에는 랜덤값을 가지지만, 인공 신경망의 가중치가 학습되는 방법과 같은 방식으로 값이 학습되며 변동된다.

# %% [markdown]
# ![](2022-02-06-13-40-43.png)

# %% [markdown]
# - Embedding()
#     - 단어를 밀집 벡터로 만들어줌
#     - (number of samples, input_length)인 2D 정수 텐서를 입력받음
#         - 각 sample 은 정수 인코딩이 된 결과 -> 정수의 시퀀스
#     - 워드 임베딩 작업을 수행하고, (number of samples, input_length, embedding word dimensionality)인 3D 텐서를 리턴

# %%
# 1. 토큰화 
tokenized_text = [['Hope', 'to', 'see', 'you', 'soon'], ['Nice', 'to', 'see', 'you', 'again']]

# 2. 각 단어에 대한 정수 인코딩
encoded_text = [[0, 1, 2, 3, 4],[5, 1, 2, 3, 6]]

# 3. 위 정수 인코딩 데이터가 아래의 임베딩 층의 입력이 된다.
vocab_size = 7
embedding_dim = 2
# Embedding - (단어 집합의 크기, 임베딩 벡터의 출력 차원, 입력 시퀀스의 길이)
Embedding(vocab_size, embedding_dim, input_length=5)


# 각 정수는 아래의 테이블의 인덱스로 사용되며 Embedding()은 각 단어마다 임베딩 벡터를 리턴한다.
+------------+------------+
|   index    | embedding  |
+------------+------------+
|     0      | [1.2, 3.1] |
|     1      | [0.1, 4.2] |
|     2      | [1.0, 3.1] |
|     3      | [0.3, 2.1] |
|     4      | [2.2, 1.4] |
|     5      | [0.7, 1.7] |
|     6      | [4.1, 2.0] |
+------------+------------+

# 위의 표는 임베딩 벡터가 된 결과를 예로서 정리한 것이고 Embedding()의 출력인 3D 텐서를 보여주는 것이 아님.

# %% [markdown]
# ## 3. 모델링(Modeling)
# - Sequential()에 임베딩 층 추가하기

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding

model = Sequential()
model.add(Embedding(vocab_size, output_dim, input_length))
# Out:
# Metal device set to: Apple M1 Max
#
# systemMemory: 32.00 GB
# maxCacheSize: 10.67 GB
# 2022-02-06 17:04:12.367557: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-02-06 17:04:12.367677: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/jw/_38j243d5qq977z0w467cxq00000gn/T/ipykernel_63271/3190806667.py in <module>
#       3
#       4 model = Sequential()
# ----> 5 model.add(Embedding(vocab_size, output_dim, input_length))
#
# NameError: name 'vocab_size' is not defined

# %% [markdown]
# ## 4. 함수형 모델(Functional API)
# - 각 층을 일종의 함수로 정의한다
# - 각 함수를 조합하기 위한 연산자들을 활용하여 신경망을 설계한다.

# %% [markdown]
# #### 1) 전결합 피드 포워드 신경망(Fully-connected FFNN)
# - Sequential API와는 다르게 입력 데이터의 크기(shape)를 인자로 입력층을 정의해야 한다.

# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model



# 10개의 입력을 받는 입력층 만들기
inputs = Input(shape=(10,))
hidden1 = Dense(64, activation='relu')(inputs)
hidden2 = Dense(64, activation='relu')(hidden1)
output = Dense(1, activation='sigmoid')(hidden2)

model = Model(inputs=inputs, outputs=output)

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])


# 은닉층과 출력층의 변수를 통일해도 됨
inputs = Input(shape=(10,))
x = Dense(8, activation="relu")(inputs)
x = Dense(4, activation="relu")(x)
x = Dense(1, activation="linear")(x)
model = Model(inputs, x)

# %% [markdown]
# #### 2) 선형 회귀(Linear Regression)

# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model

X = [1,2,3,4,5,6,7,8,9]
y = [11,22,33,44,53,66,77,87,95]

inputs = Input(shape=(1,))
output = Dense(1, activation='linear')(inputs)
linear_model = Model(inputs, output)

sgd = optimizers.SGD(lr=0.01)

linear_model.compile(optimizer=sgd, loss='mse', metrics=['mse'])
linear_model.fit(X, y , epochs=300)
# Out:
# /Users/sunny/miniforge3/envs/py38/lib/python3.8/site-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 2022-02-06 17:14:44.803272: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-02-06 17:14:44.897140: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Epoch 1/300
# 1/1 [==============================] - 1s 870ms/step - loss: 4411.8408 - mse: 4411.8408
# Epoch 2/300
# 1/1 [==============================] - 0s 5ms/step - loss: 543.9653 - mse: 543.9653
# Epoch 3/300
# 1/1 [==============================] - 0s 5ms/step - loss: 68.0505 - mse: 68.0505
# Epoch 4/300
# 1/1 [==============================] - 0s 6ms/step - loss: 9.4913 - mse: 9.4913
# Epoch 5/300
# 1/1 [==============================] - 0s 6ms/step - loss: 2.2844 - mse: 2.2844
# Epoch 6/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.3961 - mse: 1.3961
# Epoch 7/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2853 - mse: 1.2853
# Epoch 8/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2702 - mse: 1.2702
# Epoch 9/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.2668 - mse: 1.2668
# Epoch 10/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2649 - mse: 1.2649
# Epoch 11/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.2632 - mse: 1.2632
# Epoch 12/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2615 - mse: 1.2615
# Epoch 13/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.2599 - mse: 1.2599
# Epoch 14/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2582 - mse: 1.2582
# Epoch 15/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2566 - mse: 1.2566
# Epoch 16/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.2550 - mse: 1.2550
# Epoch 17/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2534 - mse: 1.2534
# Epoch 18/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.2518 - mse: 1.2518
# Epoch 19/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2503 - mse: 1.2503
# Epoch 20/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2487 - mse: 1.2487
# Epoch 21/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2471 - mse: 1.2471
# Epoch 22/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2456 - mse: 1.2456
# Epoch 23/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2441 - mse: 1.2441
# Epoch 24/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2426 - mse: 1.2426
# Epoch 25/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2411 - mse: 1.2411
# Epoch 26/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2396 - mse: 1.2396
# Epoch 27/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2381 - mse: 1.2381
# Epoch 28/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2367 - mse: 1.2367
# Epoch 29/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.2352 - mse: 1.2352
# Epoch 30/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2338 - mse: 1.2338
# Epoch 31/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2323 - mse: 1.2323
# Epoch 32/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2309 - mse: 1.2309
# Epoch 33/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.2295 - mse: 1.2295
# Epoch 34/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2281 - mse: 1.2281
# Epoch 35/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2268 - mse: 1.2268
# Epoch 36/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.2254 - mse: 1.2254
# Epoch 37/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.2240 - mse: 1.2240
# Epoch 38/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2227 - mse: 1.2227
# Epoch 39/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2214 - mse: 1.2214
# Epoch 40/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2200 - mse: 1.2200
# Epoch 41/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.2187 - mse: 1.2187
# Epoch 42/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2174 - mse: 1.2174
# Epoch 43/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.2161 - mse: 1.2161
# Epoch 44/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.2148 - mse: 1.2148
# Epoch 45/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.2136 - mse: 1.2136
# Epoch 46/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.2123 - mse: 1.2123
# Epoch 47/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.2111 - mse: 1.2111
# Epoch 48/300
# 1/1 [==============================] - 0s 26ms/step - loss: 1.2098 - mse: 1.2098
# Epoch 49/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.2086 - mse: 1.2086
# Epoch 50/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.2074 - mse: 1.2074
# Epoch 51/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.2062 - mse: 1.2062
# Epoch 52/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2050 - mse: 1.2050
# Epoch 53/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2038 - mse: 1.2038
# Epoch 54/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2026 - mse: 1.2026
# Epoch 55/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.2014 - mse: 1.2014
# Epoch 56/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2003 - mse: 1.2003
# Epoch 57/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1991 - mse: 1.1991
# Epoch 58/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1980 - mse: 1.1980
# Epoch 59/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1968 - mse: 1.1968
# Epoch 60/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1957 - mse: 1.1957
# Epoch 61/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1946 - mse: 1.1946
# Epoch 62/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1935 - mse: 1.1935
# Epoch 63/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1924 - mse: 1.1924
# Epoch 64/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1913 - mse: 1.1913
# Epoch 65/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1902 - mse: 1.1902
# Epoch 66/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1892 - mse: 1.1892
# Epoch 67/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1881 - mse: 1.1881
# Epoch 68/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1871 - mse: 1.1871
# Epoch 69/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1860 - mse: 1.1860
# Epoch 70/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1850 - mse: 1.1850
# Epoch 71/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1840 - mse: 1.1840
# Epoch 72/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1829 - mse: 1.1829
# Epoch 73/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1819 - mse: 1.1819
# Epoch 74/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1809 - mse: 1.1809
# Epoch 75/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1799 - mse: 1.1799
# Epoch 76/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1790 - mse: 1.1790
# Epoch 77/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1780 - mse: 1.1780
# Epoch 78/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1770 - mse: 1.1770
# Epoch 79/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1760 - mse: 1.1760
# Epoch 80/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1751 - mse: 1.1751
# Epoch 81/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1742 - mse: 1.1742
# Epoch 82/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1732 - mse: 1.1732
# Epoch 83/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1723 - mse: 1.1723
# Epoch 84/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1714 - mse: 1.1714
# Epoch 85/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1704 - mse: 1.1704
# Epoch 86/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1695 - mse: 1.1695
# Epoch 87/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1686 - mse: 1.1686
# Epoch 88/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1678 - mse: 1.1678
# Epoch 89/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1669 - mse: 1.1669
# Epoch 90/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1660 - mse: 1.1660
# Epoch 91/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1651 - mse: 1.1651
# Epoch 92/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1643 - mse: 1.1643
# Epoch 93/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1634 - mse: 1.1634
# Epoch 94/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1626 - mse: 1.1626
# Epoch 95/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1617 - mse: 1.1617
# Epoch 96/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1609 - mse: 1.1609
# Epoch 97/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1601 - mse: 1.1601
# Epoch 98/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1592 - mse: 1.1592
# Epoch 99/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1584 - mse: 1.1584
# Epoch 100/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1576 - mse: 1.1576
# Epoch 101/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1568 - mse: 1.1568
# Epoch 102/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1560 - mse: 1.1560
# Epoch 103/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1552 - mse: 1.1552
# Epoch 104/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1544 - mse: 1.1544
# Epoch 105/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1537 - mse: 1.1537
# Epoch 106/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1529 - mse: 1.1529
# Epoch 107/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1521 - mse: 1.1521
# Epoch 108/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1514 - mse: 1.1514
# Epoch 109/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1506 - mse: 1.1506
# Epoch 110/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1499 - mse: 1.1499
# Epoch 111/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1491 - mse: 1.1491
# Epoch 112/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1484 - mse: 1.1484
# Epoch 113/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1477 - mse: 1.1477
# Epoch 114/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1470 - mse: 1.1470
# Epoch 115/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1463 - mse: 1.1463
# Epoch 116/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1455 - mse: 1.1455
# Epoch 117/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1448 - mse: 1.1448
# Epoch 118/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1442 - mse: 1.1442
# Epoch 119/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1435 - mse: 1.1435
# Epoch 120/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1428 - mse: 1.1428
# Epoch 121/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1421 - mse: 1.1421
# Epoch 122/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1414 - mse: 1.1414
# Epoch 123/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1407 - mse: 1.1407
# Epoch 124/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1401 - mse: 1.1401
# Epoch 125/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1394 - mse: 1.1394
# Epoch 126/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1388 - mse: 1.1388
# Epoch 127/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1381 - mse: 1.1381
# Epoch 128/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1375 - mse: 1.1375
# Epoch 129/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1369 - mse: 1.1369
# Epoch 130/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1362 - mse: 1.1362
# Epoch 131/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1356 - mse: 1.1356
# Epoch 132/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1350 - mse: 1.1350
# Epoch 133/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1344 - mse: 1.1344
# Epoch 134/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1337 - mse: 1.1337
# Epoch 135/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1331 - mse: 1.1331
# Epoch 136/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1325 - mse: 1.1325
# Epoch 137/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1319 - mse: 1.1319
# Epoch 138/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1314 - mse: 1.1314
# Epoch 139/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1308 - mse: 1.1308
# Epoch 140/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1302 - mse: 1.1302
# Epoch 141/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1296 - mse: 1.1296
# Epoch 142/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1290 - mse: 1.1290
# Epoch 143/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1285 - mse: 1.1285
# Epoch 144/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1279 - mse: 1.1279
# Epoch 145/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1274 - mse: 1.1274
# Epoch 146/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1268 - mse: 1.1268
# Epoch 147/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1262 - mse: 1.1262
# Epoch 148/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1257 - mse: 1.1257
# Epoch 149/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1252 - mse: 1.1252
# Epoch 150/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1246 - mse: 1.1246
# Epoch 151/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1241 - mse: 1.1241
# Epoch 152/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1236 - mse: 1.1236
# Epoch 153/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1231 - mse: 1.1231
# Epoch 154/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1225 - mse: 1.1225
# Epoch 155/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1220 - mse: 1.1220
# Epoch 156/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1215 - mse: 1.1215
# Epoch 157/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1210 - mse: 1.1210
# Epoch 158/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1205 - mse: 1.1205
# Epoch 159/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1200 - mse: 1.1200
# Epoch 160/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1195 - mse: 1.1195
# Epoch 161/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1190 - mse: 1.1190
# Epoch 162/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1185 - mse: 1.1185
# Epoch 163/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1181 - mse: 1.1181
# Epoch 164/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1176 - mse: 1.1176
# Epoch 165/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1171 - mse: 1.1171
# Epoch 166/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1166 - mse: 1.1166
# Epoch 167/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1162 - mse: 1.1162
# Epoch 168/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1157 - mse: 1.1157
# Epoch 169/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1153 - mse: 1.1153
# Epoch 170/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1148 - mse: 1.1148
# Epoch 171/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1143 - mse: 1.1143
# Epoch 172/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1139 - mse: 1.1139
# Epoch 173/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1135 - mse: 1.1135
# Epoch 174/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1130 - mse: 1.1130
# Epoch 175/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1126 - mse: 1.1126
# Epoch 176/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1122 - mse: 1.1122
# Epoch 177/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1117 - mse: 1.1117
# Epoch 178/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1113 - mse: 1.1113
# Epoch 179/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1109 - mse: 1.1109
# Epoch 180/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1105 - mse: 1.1105
# Epoch 181/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1100 - mse: 1.1100
# Epoch 182/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1096 - mse: 1.1096
# Epoch 183/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1092 - mse: 1.1092
# Epoch 184/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1088 - mse: 1.1088
# Epoch 185/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1084 - mse: 1.1084
# Epoch 186/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1080 - mse: 1.1080
# Epoch 187/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1076 - mse: 1.1076
# Epoch 188/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1072 - mse: 1.1072
# Epoch 189/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1068 - mse: 1.1068
# Epoch 190/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1065 - mse: 1.1065
# Epoch 191/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1061 - mse: 1.1061
# Epoch 192/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1057 - mse: 1.1057
# Epoch 193/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1053 - mse: 1.1053
# Epoch 194/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1050 - mse: 1.1050
# Epoch 195/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1046 - mse: 1.1046
# Epoch 196/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1042 - mse: 1.1042
# Epoch 197/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1039 - mse: 1.1039
# Epoch 198/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1035 - mse: 1.1035
# Epoch 199/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1031 - mse: 1.1031
# Epoch 200/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1028 - mse: 1.1028
# Epoch 201/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1024 - mse: 1.1024
# Epoch 202/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1021 - mse: 1.1021
# Epoch 203/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1017 - mse: 1.1017
# Epoch 204/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1014 - mse: 1.1014
# Epoch 205/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1011 - mse: 1.1011
# Epoch 206/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1007 - mse: 1.1007
# Epoch 207/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1004 - mse: 1.1004
# Epoch 208/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1000 - mse: 1.1000
# Epoch 209/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0997 - mse: 1.0997
# Epoch 210/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0994 - mse: 1.0994
# Epoch 211/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0991 - mse: 1.0991
# Epoch 212/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0987 - mse: 1.0987
# Epoch 213/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0984 - mse: 1.0984
# Epoch 214/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0981 - mse: 1.0981
# Epoch 215/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0978 - mse: 1.0978
# Epoch 216/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0975 - mse: 1.0975
# Epoch 217/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0972 - mse: 1.0972
# Epoch 218/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0969 - mse: 1.0969
# Epoch 219/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0966 - mse: 1.0966
# Epoch 220/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0963 - mse: 1.0963
# Epoch 221/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0960 - mse: 1.0960
# Epoch 222/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0957 - mse: 1.0957
# Epoch 223/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0954 - mse: 1.0954
# Epoch 224/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0951 - mse: 1.0951
# Epoch 225/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0948 - mse: 1.0948
# Epoch 226/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0945 - mse: 1.0945
# Epoch 227/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0942 - mse: 1.0942
# Epoch 228/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0939 - mse: 1.0939
# Epoch 229/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0937 - mse: 1.0937
# Epoch 230/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0934 - mse: 1.0934
# Epoch 231/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0931 - mse: 1.0931
# Epoch 232/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0928 - mse: 1.0928
# Epoch 233/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0926 - mse: 1.0926
# Epoch 234/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0923 - mse: 1.0923
# Epoch 235/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0920 - mse: 1.0920
# Epoch 236/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0918 - mse: 1.0918
# Epoch 237/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0915 - mse: 1.0915
# Epoch 238/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0913 - mse: 1.0913
# Epoch 239/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0910 - mse: 1.0910
# Epoch 240/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0907 - mse: 1.0907
# Epoch 241/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0905 - mse: 1.0905
# Epoch 242/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0902 - mse: 1.0902
# Epoch 243/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0900 - mse: 1.0900
# Epoch 244/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0897 - mse: 1.0897
# Epoch 245/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0895 - mse: 1.0895
# Epoch 246/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0893 - mse: 1.0893
# Epoch 247/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0890 - mse: 1.0890
# Epoch 248/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0888 - mse: 1.0888
# Epoch 249/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0885 - mse: 1.0885
# Epoch 250/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0883 - mse: 1.0883
# Epoch 251/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0881 - mse: 1.0881
# Epoch 252/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0878 - mse: 1.0878
# Epoch 253/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0876 - mse: 1.0876
# Epoch 254/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0874 - mse: 1.0874
# Epoch 255/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0872 - mse: 1.0872
# Epoch 256/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0869 - mse: 1.0869
# Epoch 257/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0867 - mse: 1.0867
# Epoch 258/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0865 - mse: 1.0865
# Epoch 259/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0863 - mse: 1.0863
# Epoch 260/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0861 - mse: 1.0861
# Epoch 261/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0858 - mse: 1.0858
# Epoch 262/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0856 - mse: 1.0856
# Epoch 263/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0854 - mse: 1.0854
# Epoch 264/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0852 - mse: 1.0852
# Epoch 265/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0850 - mse: 1.0850
# Epoch 266/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0848 - mse: 1.0848
# Epoch 267/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0846 - mse: 1.0846
# Epoch 268/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0844 - mse: 1.0844
# Epoch 269/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0842 - mse: 1.0842
# Epoch 270/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0840 - mse: 1.0840
# Epoch 271/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0838 - mse: 1.0838
# Epoch 272/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0836 - mse: 1.0836
# Epoch 273/300
# 1/1 [==============================] - 0s 15ms/step - loss: 1.0834 - mse: 1.0834
# Epoch 274/300
# 1/1 [==============================] - 0s 14ms/step - loss: 1.0832 - mse: 1.0832
# Epoch 275/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0830 - mse: 1.0830
# Epoch 276/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0828 - mse: 1.0828
# Epoch 277/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0826 - mse: 1.0826
# Epoch 278/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0825 - mse: 1.0825
# Epoch 279/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0823 - mse: 1.0823
# Epoch 280/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0821 - mse: 1.0821
# Epoch 281/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0819 - mse: 1.0819
# Epoch 282/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0817 - mse: 1.0817
# Epoch 283/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0815 - mse: 1.0815
# Epoch 284/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0814 - mse: 1.0814
# Epoch 285/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0812 - mse: 1.0812
# Epoch 286/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0810 - mse: 1.0810
# Epoch 287/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0808 - mse: 1.0808
# Epoch 288/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0807 - mse: 1.0807
# Epoch 289/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0805 - mse: 1.0805
# Epoch 290/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0803 - mse: 1.0803
# Epoch 291/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0802 - mse: 1.0802
# Epoch 292/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0800 - mse: 1.0800
# Epoch 293/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0798 - mse: 1.0798
# Epoch 294/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0797 - mse: 1.0797
# Epoch 295/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0795 - mse: 1.0795
# Epoch 296/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0793 - mse: 1.0793
# Epoch 297/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0792 - mse: 1.0792
# Epoch 298/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0790 - mse: 1.0790
# Epoch 299/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0789 - mse: 1.0789
# Epoch 300/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0787 - mse: 1.0787

# %% [markdown]
# #### 3) 로지스틱 회귀(Logistic Regression)

# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model

inputs = Input(shape=(3,))
output = Dense(1, activation='sigmoid')(inputs)
logistic_model = Model(inputs, output)

# %% [markdown]
# #### 4) 다중 입력을 받는 모델
# - 함수형 API 를 사용하면 다중 입력,출력을 가지는 모델을 만들 수 있다.

# %%
from tensorflow.keras.layers import Input, Dense, concatenate
from tensorflow.keras.models import Model

# 두 개의 입력층을 정의
inputA = Input(shape=(64,))
inputB = Input(shape=(128,))

# 첫번째 입력층으로부터 분기되어 진행되는 인공 신경망을 정의
x = Dense(16, activation="relu")(inputA)
x = Dense(8, activation="relu")(x)
x = Model(inputs=inputA, outputs=x)

# 두번째 입력층으로부터 분기되어 진행되는 인공 신경망을 정의
y = Dense(64, activation="relu")(inputB)
y = Dense(32, activation="relu")(y)
y = Dense(8, activation="relu")(y)
y = Model(inputs=inputB, outputs=y)

# 두개의 인공 신경망의 출력을 연결(concatenate)
result = concatenate([x.output, y.output])

z = Dense(2, activation="relu")(result)
z = Dense(1, activation="linear")(z)

model = Model(inputs=[x.input, y.input], outputs=z)

# %% [markdown]
# #### 5) RNN(Recurrence Neural Network) 은닉층 사용하기

# %%
from tensorflow.keras.layers import Input, Dense, LSTM
from tensorflow.keras.models import Model

inputs = Input(shape=(50,1))
lstm_layer = LSTM(10)(inputs)
x = Dense(10, activation='relu')(lstm_layer)
output = Dense(1, activation='sigmoid')(x)

model = Model(inputs=inputs, outputs=output)

# %% [markdown]
# ## 5. 케라스 서브클래싱 API(Keras Subclassing API)
# - 케라스 구현 방식
#     - Sequential
#     - Functional
#     - Subclassing

# %%
# 선형회귀를 Subclassing API 로 구현하기
import tensorflow as tf

class LinearRegression(tf.keras.Model):
    def __init__(self):
        super(LinearRegression, self).__init__()
        self.linear_layer = tf.keras.layers.Dense(1, input_dim=1, activation='linear')
    
    def call(self, x):
        y_pred = self.linear_layer(x)
        
        return y_pred

# %%
model = LinearRegression()

X = [1, 2, 3, 4, 5, 6, 7, 8, 9] # 공부하는 시간
y = [11, 22, 33, 44, 53, 66, 77, 87, 95] # 각 공부하는 시간에 맵핑되는 성적

sgd = tf.keras.optimizers.SGD(lr=0.01)
model.compile(optimizer=sgd, loss='mse', metrics=['mse'])
model.fit(X, y, epochs=300)

# %% [markdown]
# #### ***** 3가지 구현 방식 비교 *****

# %% [markdown]
# - 1) Sequential API
#
#     - 장점 : 단순하게 층을 쌓는 방식으로 쉽고 사용하기가 간단합니다.
#     - 단점 : 다수의 입력(multi-input), 다수의 출력(multi-output)을 가진 모델 또는 층 간의 연결(concatenate)이나 덧셈(Add)과 같은 연산을 하는 모델을 구현하기에는 적합하지 않습니다. 이런 모델들의 구현은 Functional API를 사용해야 합니다.
#
# - 2) Functional API
#
#     - 장점 : Sequential API로는 구현하기 어려운 복잡한 모델들을 구현할 수 있습니다.
#     - 단점 : 입력의 크기(shape)를 명시한 입력층(Input layer)을 모델의 앞단에 정의해주어야 합니다. 가령, 아래의 코드를 봅시다.
#
#
# ```python
# # 선형 회귀 구현 코드의 일부 발췌
# inputs = Input(shape=(1,)) # <-- 해당 부분
# output = Dense(1, activation='linear')(inputs)
# linear_model = Model(inputs, output)
#
# sgd = optimizers.SGD(lr=0.01)
#
# linear_model.compile(optimizer=sgd, loss='mse', metrics=['mse'])
# linear_model.fit(X, y, epochs=300)
# ```
# - 3) Subclassing API
#
#     - 장점 : Functional API로도 구현할 수 없는 모델들조차 구현이 가능합니다.
#     - 단점 : 객체 지향 프로그래밍(Object-oriented programming)에 익숙해야 하므로 코드 사용이 가장 까다롭습니다.
